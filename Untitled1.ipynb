# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('powerplant.csv',  encoding = 'utf8')
data.head(100)
# Out:
#    country country_long                                               name  \
# 0      AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1      AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2      AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3      AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4      AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
# ..     ...          ...                                                ...
# 95     ARG    Argentina           CENTRAL TERMICA BRIGADIER LOPEZ (ENARSA)
# 96     ARG    Argentina           CENTRAL TERMICA DE CICLO COMBINADO SALTA
# 97     ARG    Argentina                          CENTRAL TERMICA GÜEMES SA
# 98     ARG    Argentina                           CENTRAL TERMICA LA BANDA
# 99     ARG    Argentina                      CENTRAL TERMICA PIQUIRENDA SA
#
# ...

# %%
data1 = data[['country_long', 'name', 'capacity_mw', 'latitude', 'longitude', 'primary_fuel','commissioning_year', 'owner']]
data1.head(100)
# Out:
#    country_long                                               name  \
# 0   Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1   Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2   Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3   Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4   Afghanistan            Northwest Kabul Power Plant Afghanistan
# ..          ...                                                ...
# 95    Argentina           CENTRAL TERMICA BRIGADIER LOPEZ (ENARSA)
# 96    Argentina           CENTRAL TERMICA DE CICLO COMBINADO SALTA
# 97    Argentina                          CENTRAL TERMICA GÜEMES SA
# 98    Argentina                           CENTRAL TERMICA LA BANDA
# 99    Argentina                      CENTRAL TERMICA PIQUIRENDA SA
#
#     capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0         33.00   32.3220    65.1190        Hydro                 NaN
# ...

# %%
data1['commissioning_year']= data1['commissioning_year'].fillna('0')
# Out:
# /home/voja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1['commissioning_year'] = data1['commissioning_year'].astype(int)
#data1['commissioning_year'] = pd.to_datetime(data1['commissioning_year'])
data1.head(30)
# Out:
# /home/voja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    country_long                                               name  \
# 0   Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1   Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2   Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3   Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4   Afghanistan            Northwest Kabul Power Plant Afghanistan
# 5   Afghanistan  Pul-e-Khumri Hydroelectric Power Plant Afghani...
# 6   Afghanistan   Sarobi Dam Hydroelectric Power Plant Afghanistan
# ...

# %%
pd.to_datetime(data1['commissioning_year'])
data1.head()
data1.dtypes
# Out:
# country_long           object
# name                   object
# capacity_mw           float64
# latitude              float64
# longitude             float64
# primary_fuel           object
# commissioning_year      int64
# owner                  object
# dtype: object

# %%
data1 = data1[['name', 'latitude', 'longitude', 'commissioning_year']]
data1.to_csv('ppnames.csv',index=False)
