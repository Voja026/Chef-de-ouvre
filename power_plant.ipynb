# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('powerplant.csv')
data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
data1 = data[['country_long', 'name', 'capacity_mw', 'latitude', 'longitude', 'primary_fuel','commissioning_year', 'owner']]
data1
# Out:
#       country_long                                               name  \
# 0      Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1      Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2      Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3      Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4      Afghanistan            Northwest Kabul Power Plant Afghanistan
# ...            ...                                                ...
# 29905       Zambia                                              Ndola
# 29906       Zambia                                              Nkana
# 29907       Zambia                                     Victoria Falls
# 29908     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
# 29909     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
#        capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# ...

# %%
data2 = pd.to_datetime(data1['commissioning_year'])
data2.head(10)
# Out:
# 0                             NaT
# 1                             NaT
# 2                             NaT
# 3                             NaT
# 4                             NaT
# 5                             NaT
# 6                             NaT
# 7   1970-01-01 00:00:00.000001965
# 8   1970-01-01 00:00:00.000001978
# 9   1970-01-01 00:00:00.000001985
# Name: commissioning_year, dtype: datetime64[ns]

# %%
data1['owner'] = data1['owner'].fillna('state')
data1
# Out:
# /home/voja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       country_long                                               name  \
# 0      Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1      Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2      Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3      Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4      Afghanistan            Northwest Kabul Power Plant Afghanistan
# ...            ...                                                ...
# ...

# %%
data_ppnames = data1[['name','latitude','longitude','commissioning_year']]
data_ppnames
# Out:
#                                                     name  latitude  longitude  \
# 0           Kajaki Hydroelectric Power Plant Afghanistan   32.3220    65.1190
# 1          Mahipar Hydroelectric Power Plant Afghanistan   34.5560    69.4787
# 2       Naghlu Dam Hydroelectric Power Plant Afghanistan   34.6410    69.7170
# 3      Nangarhar (Darunta) Hydroelectric Power Plant ...   34.4847    70.3633
# 4                Northwest Kabul Power Plant Afghanistan   34.5638    69.1134
# ...                                                  ...       ...        ...
# 29905                                              Ndola  -12.9667    28.6333
# 29906                                              Nkana  -12.8167    28.2000
# 29907                                     Victoria Falls  -17.9167    25.8500
# 29908                   Hwange Coal Power Plant Zimbabwe  -18.3835    26.4700
# 29909  Kariba Dam South Hydroelectric Power Station Z...  -16.5222    28.7619
#
#        commissioning_year
# ...

# %%
data_ppnames.dtypes
# Out:
# name                   object
# latitude              float64
# longitude             float64
# commissioning_year    float64
# dtype: object
