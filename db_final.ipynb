# %%
import numpy as np
import pandas as pd
import psycopg2

# %%
csv_file = "updated_b.csv"
df_plants = pd.read_csv(csv_file,error_bad_lines=False)
csv_file = "socio.csv"
df_pop = pd.read_csv(csv_file,error_bad_lines=False)
csv_file = "CO2.csv"
df_co2 = pd.read_csv(csv_file,error_bad_lines=False)

# %%
# Read the powerplants csv file
df_plants
# Out:
#       country_long                                               name  \
# 0      Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 1      Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 2      Afghanistan   Sarobi Dam Hydroelectric Power Plant Afghanistan
# 3      Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 4      Afghanistan            Northwest Kabul Power Plant Afghanistan
# ...            ...                                                ...
# 29902       Zambia                                              Ndola
# 29903       Zambia                                             Kariba
# 29904       Zambia                                        Kafue Gorge
# 29905     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
# 29906     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
#
#        capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0             1.00   34.6410    69.7170        Hydro                1000
# 1            11.55   34.4847    70.3633        Hydro                1000
# 2             0.22   34.5865    69.7757        Hydro                1000
# 3             0.33   32.3220    65.1190        Hydro                1000
# 4             0.42   34.5638    69.1134          Gas                1000
# ...            ...       ...        ...          ...                 ...
# 29902         0.50  -12.9667    28.6333          Oil                1000
# 29903         9.30  -16.5222    28.7619        Hydro                1000
# 29904         9.90  -15.8089    28.4199        Hydro                1971
# 29905         7.50  -16.5222    28.7619        Hydro                1000
# 29906         9.20  -18.3835    26.4700         Coal                1000
#
#        owner Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0      state        NaN        NaN         NaN
# 1      state        NaN        NaN         NaN
# 2      state        NaN        NaN         NaN
# 3      state        NaN        NaN         NaN
# 4      state        NaN        NaN         NaN
# ...      ...        ...        ...         ...
# 29902  ZESCO        NaN        NaN         NaN
# 29903  ZESCO        NaN        NaN         NaN
# 29904  ZESCO        NaN        NaN         NaN
# 29905  state        NaN        NaN         NaN
# 29906  state        NaN        NaN         NaN
#
# [29907 rows x 11 columns]

# %%
#added population CSV
df_group = df_pop.groupby('Country', as_index=False).last()
df_group.drop(columns= 'GDP-PPP (Million Intl$ (2011))').join(df_plants)
# Out:
#          Country    Year  Population (People)  GDP-USD (Million US$ (2010))  \
# 0    Afghanistan  2014.0         3.275802e+07                  1.999032e+04
# 1        Albania  2014.0         2.889104e+06                  1.276823e+04
# 2        Algeria  2014.0         3.911331e+07                  1.828894e+05
# 3        Andorra  2014.0         7.922300e+04                  3.127736e+03
# 4         Angola  2014.0         2.692047e+07                  1.008863e+05
# ..           ...     ...                  ...                           ...
# 188      Vietnam  2014.0         9.072890e+07                  1.448347e+05
# 189        World  2014.0         7.268986e+09                  7.347854e+07
# 190        Yemen  2014.0         2.624633e+07                  2.890029e+04
# 191       Zambia  2014.0         1.562097e+07                  2.531884e+04
# 192     Zimbabwe  2014.0         1.541168e+07                  1.437213e+04
#
#     country_long                                               name  \
# 0    Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 1    Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 2    Afghanistan   Sarobi Dam Hydroelectric Power Plant Afghanistan
# 3    Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 4    Afghanistan            Northwest Kabul Power Plant Afghanistan
# ..           ...                                                ...
# 188    Argentina                                   C.T. SAN VICENTE
# 189    Argentina                   PARQUE EOLICO RAWSON II (ENARSA)
# 190    Argentina           CENTRAL TERMICA BRIGADIER LOPEZ (ENARSA)
# 191    Argentina                               H. PICHI PICUN LEUFU
# 192    Argentina                          PARQUE EOLICO EL TORDILLO
#
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0           1.00   34.6410    69.7170        Hydro                1000
# 1          11.55   34.4847    70.3633        Hydro                1000
# 2           0.22   34.5865    69.7757        Hydro                1000
# 3           0.33   32.3220    65.1190        Hydro                1000
# 4           0.42   34.5638    69.1134          Gas                1000
# ..           ...       ...        ...          ...                 ...
# 188        27.60  -35.0241   -58.4237          Oil                1000
# 189        28.80  -43.3522   -65.1734         Wind                1000
# 190         2.80  -31.7112   -60.7811          Gas                2013
# 191         2.85  -40.0120   -69.9918        Hydro                1999
# 192         0.03  -45.8507   -67.9081         Wind                1000
#
#                                      owner Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0                                    state        NaN        NaN         NaN
# 1                                    state        NaN        NaN         NaN
# 2                                    state        NaN        NaN         NaN
# 3                                    state        NaN        NaN         NaN
# 4                                    state        NaN        NaN         NaN
# ..                                     ...        ...        ...         ...
# 188                                 ENARSA        NaN        NaN         NaN
# 189                                 ENARSA        NaN        NaN         NaN
# 190                                 ENARSA        NaN        NaN         NaN
# 191                      PETROBRAS ENERGIA        NaN        NaN         NaN
# 192  VIENTOS DE LA PATAGONIA I.S.A./ENARSA        NaN        NaN         NaN
#
# [193 rows x 15 columns]

# %%
#added CO2 CSV
df_co2_group = df_co2.groupby('Country').last()

# %%
column_select = ['country_long','Population (People)','name','capacity_mw','primary_fuel','commissioning_year','Country','latitude','longitude','GDP-USD (Million US$ (2010))']

# %%
df_plants_pop = df_plants.merge(df_group, how='outer' ,left_on ='country_long', right_on = 'Country' )[column_select].dropna()
df_plants_pop
# Out:
#       country_long  Population (People)  \
# 0      Afghanistan           32758020.0
# 1      Afghanistan           32758020.0
# 2      Afghanistan           32758020.0
# 3      Afghanistan           32758020.0
# 4      Afghanistan           32758020.0
# ...            ...                  ...
# 29902       Zambia           15620974.0
# 29903       Zambia           15620974.0
# 29904       Zambia           15620974.0
# 29905     Zimbabwe           15411675.0
# 29906     Zimbabwe           15411675.0
#
#                                                     name  capacity_mw  \
# 0       Naghlu Dam Hydroelectric Power Plant Afghanistan         1.00
# 1      Nangarhar (Darunta) Hydroelectric Power Plant ...        11.55
# 2       Sarobi Dam Hydroelectric Power Plant Afghanistan         0.22
# 3           Kajaki Hydroelectric Power Plant Afghanistan         0.33
# 4                Northwest Kabul Power Plant Afghanistan         0.42
# ...                                                  ...          ...
# 29902                                              Ndola         0.50
# 29903                                             Kariba         9.30
# 29904                                        Kafue Gorge         9.90
# 29905  Kariba Dam South Hydroelectric Power Station Z...         7.50
# 29906                   Hwange Coal Power Plant Zimbabwe         9.20
#
#       primary_fuel  commissioning_year      Country  latitude  longitude  \
# 0            Hydro              1000.0  Afghanistan   34.6410    69.7170
# 1            Hydro              1000.0  Afghanistan   34.4847    70.3633
# 2            Hydro              1000.0  Afghanistan   34.5865    69.7757
# 3            Hydro              1000.0  Afghanistan   32.3220    65.1190
# 4              Gas              1000.0  Afghanistan   34.5638    69.1134
# ...            ...                 ...          ...       ...        ...
# 29902          Oil              1000.0       Zambia  -12.9667    28.6333
# 29903        Hydro              1000.0       Zambia  -16.5222    28.7619
# 29904        Hydro              1971.0       Zambia  -15.8089    28.4199
# 29905        Hydro              1000.0     Zimbabwe  -16.5222    28.7619
# 29906         Coal              1000.0     Zimbabwe  -18.3835    26.4700
#
#        GDP-USD (Million US$ (2010))
# 0                       19990.31716
# 1                       19990.31716
# 2                       19990.31716
# 3                       19990.31716
# 4                       19990.31716
# ...                             ...
# 29902                   25318.83846
# 29903                   25318.83846
# 29904                   25318.83846
# 29905                   14372.13260
# 29906                   14372.13260
#
# [29822 rows x 10 columns]

# %%
column_select = ['country_long','name','capacity_mw','commissioning_year','primary_fuel','Country','latitude','longitude','Population (People)','GDP-USD (Million US$ (2010))','Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)']

# %%
df_merge = df_plants_pop.merge(df_co2_group , how='outer' ,left_on ='Country', right_on = 'Country' )[column_select].dropna()

# %%
df_final = df_merge.drop('Country', axis = 1)
df_final
# Out:
#       country_long                                               name  \
# 0      Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 1      Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 2      Afghanistan   Sarobi Dam Hydroelectric Power Plant Afghanistan
# 3      Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 4      Afghanistan            Northwest Kabul Power Plant Afghanistan
# ...            ...                                                ...
# 29817       Zambia                                              Ndola
# 29818       Zambia                                             Kariba
# 29819       Zambia                                        Kafue Gorge
# 29820     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
# 29821     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
#
#        capacity_mw  commissioning_year primary_fuel  latitude  longitude  \
# 0             1.00              1000.0        Hydro   34.6410    69.7170
# 1            11.55              1000.0        Hydro   34.4847    70.3633
# 2             0.22              1000.0        Hydro   34.5865    69.7757
# 3             0.33              1000.0        Hydro   32.3220    65.1190
# 4             0.42              1000.0          Gas   34.5638    69.1134
# ...            ...                 ...          ...       ...        ...
# 29817         0.50              1000.0          Oil  -12.9667    28.6333
# 29818         9.30              1000.0        Hydro  -16.5222    28.7619
# 29819         9.90              1971.0        Hydro  -15.8089    28.4199
# 29820         7.50              1000.0        Hydro  -16.5222    28.7619
# 29821         9.20              1000.0         Coal  -18.3835    26.4700
#
#        Population (People)  GDP-USD (Million US$ (2010))  \
# 0               32758020.0                   19990.31716
# 1               32758020.0                   19990.31716
# 2               32758020.0                   19990.31716
# 3               32758020.0                   19990.31716
# 4               32758020.0                   19990.31716
# ...                    ...                           ...
# 29817           15620974.0                   25318.83846
# 29818           15620974.0                   25318.83846
# 29819           15620974.0                   25318.83846
# 29820           15411675.0                   14372.13260
# 29821           15411675.0                   14372.13260
#
#        Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)
# 0                                                 9.8012
# 1                                                 9.8012
# 2                                                 9.8012
# 3                                                 9.8012
# 4                                                 9.8012
# ...                                                  ...
# 29817                                             4.2855
# 29818                                             4.2855
# 29819                                             4.2855
# 29820                                            12.1385
# 29821                                            12.1385
#
# [29822 rows x 10 columns]

# %%
def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connected to the PostgreSQL database')
        conn = psycopg2.connect(**params_dic)

    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1)
    return conn

# %%
""" Execute a single INSERT request """
def single_insert(conn, insert_req): 
    cursor = conn.cursor()
    try:
        cursor.execute(insert_req)
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    cursor.close()

# %%
df_merge.columns
# Out:
# Index(['country_long', 'name', 'capacity_mw', 'commissioning_year',
#        'primary_fuel', 'Country', 'latitude', 'longitude',
#        'Population (People)', 'GDP-USD (Million US$ (2010))',
#        'Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)'],
#       dtype='object')

# %%
def connect_db(db, user, password, host, port):
    try:
        connection = psycopg2.connect(database=db,user=user,password=password,host=host,port=port)
        print(f'Logged in {db} successfully !')
    except e:
        print(f'Could not log in to {db} !')
    return connection

# %%
conn = connect_db("plants2", "energy", "ecolo", "localhost", "5432")
cursor = conn.cursor()
# Out:
# Logged in plants2 successfully !

# %%
#"""# Inserting each row
#for i in df_final.index:
#    query = """
#    INSERT into countries(name) values('%s');
#    """ % (df_final['country_long'][i])
#    single_insert(conn, query)
# Close the connection"""

# %%
#cursor.execute("SELECT id FROM countries;")
#print(cursor.fetchall())
#print(cursor.fetchone())

# %%
"""
0 country_long 
1 name 
2 capacity_mw 
3 commissioning_year 
4 primary_fuel 
5 latitude 
6 longitud
7 Population (People) 
8 GDP-USD (Million US$ (2010))
9 Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)
"""
# Out:
# '\n0 country_long \n1 name \n2 capacity_mw \n3 commissioning_year \n4 primary_fuel \n5 latitude \n6 longitud\n7 Population (People) \n8 GDP-USD (Million US$ (2010))\n9 Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)\n'

# %%
for central_list in df_final.values:
    
    country_name = central_list[0]
    pp_name = central_list[1]
    capacity = central_list[2]
    commissioning_year = central_list[3]
    fuel = central_list[4]
    latitude = central_list[5]
    longitude = central_list[6]
    population = central_list[7]
    gdp = central_list[8]
    co2 = central_list[9]
    
    query = """
    INSERT into countries(name) values('%s')
    ON CONFLICT DO NOTHING;
    """ % (country_name)
    single_insert(conn, query)
    
    cursor.execute("SELECT id FROM countries WHERE name = %s", (country_name,))
    id_country = cursor.fetchone()[0]
    
    query = """
    INSERT into power_plants(name,capacity, commissioning_year, lat,long,fuel,id_country ) values('%s','%s','%s','%s','%s','%s','%s');
    """ % (pp_name, capacity, commissioning_year, latitude, longitude, fuel, id_country)
    single_insert(conn, query)
    
    query = """
    INSERT into economics(population,gdp_usd,id_country ) values('%s','%s','%s');
    """ % (population, gdp, id_country)
    single_insert(conn, query)
    
    query = """
    INSERT into emissions(co2, id_country) values('%s', '%s');
    """ % (co2, id_country)
    single_insert(conn, query)

# %%
cursor.execute("SELECT id FROM countries WHERE name = %s", ("France",))
cursor.fetchone()[0]
# Out:
# 8821
